# %% [markdown]
# Your task is to predict the labels corresponding to the inputs in the test set. To facilitate submission scoring, we only require predictions on a subset of the Multiome data. This subset was created by sampling 30% of the Multiome rows, and for each row, 15% of the columns. The sample of columns varies from row-to-row. All of the CITEseq labels are scored.
#
# I have two technologies
# 1. multiome
#     - chromatin accessibility
#     - gene expression
# 2. citeseq
#
# Each of the technologies meassures two things
#
# I have this weird h5 files which contain the data. How to I inspect them?
#
# Convert data into csv

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Converting .h5 files to df

# %%
def display_heads_of_train_and_test():
    for filename in os.listdir('data/test'):
        hdf = pd.HDFStore('data/test/' + filename)
        key = hdf.keys()[0]
        cite = hdf.select(key)
        print("-----------------------" + key + "-----------------------")
        print(cite.head())
    for filename in os.listdir('data/train'):
        hdf = pd.HDFStore('data/train/' + filename)
        key = hdf.keys()[0]
        cite = hdf.select(key)
        print("-----------------------" + key + "-----------------------")
        print(cite.head())

display_heads_of_train_and_test()
# Out:
# -----------------------/test_cite_inputs-----------------------
# gene_id       ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  \
# cell_id
# c2150f55becb                   0.0                       0.0
# 65b7edf8a4da                   0.0                       0.0
# c1b26cb1057b                   0.0                       0.0
# 917168fa6f83                   0.0                       0.0
# 2b29feeca86d                   0.0                       0.0
#
# gene_id       ENSG00000175899_A2M  ENSG00000245105_A2M-AS1  \
# cell_id
# c2150f55becb                  0.0                      0.0
# 65b7edf8a4da                  0.0                      0.0
# c1b26cb1057b                  0.0                      0.0
# 917168fa6f83                  0.0                      0.0
# 2b29feeca86d                  0.0                      0.0
#
# gene_id       ENSG00000166535_A2ML1  ENSG00000128274_A4GALT  \
# cell_id
# c2150f55becb                    0.0                0.000000
# ...

# %%
#the data is so fucking huge.. it would be good if i would have a folder with 500 rows only or so


'''
train/test_multi_inputs.h5 - 
train_multi_targets.h5 - 
train/test_cite_inputs.h5 - 
train_cite_targets.h5 - 

Based on them I could do a regression where I fit 

I literally have no glue how this shit looks like. can i read only the first 5 lines into a dataframe?
I could literally also try to connect to this powerful cloud for getting some power going on. sooner or later i have to do this in any case 

and now? Idk what the next steps are now. I cannot do t

if I only work on the things I want to work on than procrastination is not really the problem actually. But if I only work on the things I want to work on than I have between my projects times of illiteracy. However right now I feel most like I want to read an inpiring book in which I can get completely get lost in. 

What as nice trick I just dont have food at home. Than I only eat if its really necessary to eat. 
'''
